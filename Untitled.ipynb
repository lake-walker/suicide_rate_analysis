# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.4.1

# %%
# read in csv to be used for model
data = pd.read_csv('data/new_country_data.csv')
data = data.dropna()

# %%
# Assign the data to x and y 
X = data[['happiness_score_2015','human_development_index','gdp_percapita_2015','alcohol_consumption_percapita',\
         'health_spending_percapita_2015','private_debt_2015']]
y = data['sui_per_100k_2015'].values.reshape(-1,1)
print(X.shape,y.shape)
# Out:
# (111, 6) (111, 1)

# %%
# drop all unneccesary columns
dataset = data[['sui_per_100k_2015','happiness_score_2015','human_development_index','gdp_percapita_2015','alcohol_consumption_percapita',\
         'health_spending_percapita_2015','private_debt_2015']]
dataset.head()
# Out:
#    sui_per_100k_2015  happiness_score_2015  human_development_index  \
# 0                6.6                  3.58                     0.46
# 1                5.3                  4.96                     0.73
# 2                3.4                  5.60                     0.74
# 3                8.7                  6.57                     0.84
# 4               12.2                  7.28                     0.94
#
#    gdp_percapita_2015  alcohol_consumption_percapita  \
# 0              578.47                            0.2
# 1             3952.83                            7.5
# 2             4177.89                            0.9
# 3            13789.06                            9.8
# 4            56748.42                           10.6
#
#    health_spending_percapita_2015  private_debt_2015
# 0                           58.91               3.70
# 1                          192.89              44.54
# 2                          291.55              21.26
# 3                         1531.48              18.70
# 4                         4860.37             199.47

# %%
# split the data into train and test
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
# inspect the data
sns.pairplot(dataset[['sui_per_100k_2015','happiness_score_2015','human_development_index','gdp_percapita_2015','alcohol_consumption_percapita',\
         'health_spending_percapita_2015','private_debt_2015']], diag_kind='kde')

# %%
# look at overall statistics
dataset.describe().transpose()
# Out:
#                                 count          mean           std     min  \
# sui_per_100k_2015               111.0     10.042342      5.027082    2.00
# happiness_score_2015            111.0      5.473423      1.208934    2.84
# human_development_index         111.0      0.710811      0.164135    0.35
# gdp_percapita_2015              111.0  15982.017568  20600.966332  305.55
# alcohol_consumption_percapita   111.0      6.381081      4.201742    0.00
# health_spending_percapita_2015  111.0   1313.155045   1980.498880   19.46
# private_debt_2015               111.0     87.905676     81.634473    3.70
#
#                                      25%      50%        75%        max
# sui_per_100k_2015                  6.000    10.00     13.000      28.80
# happiness_score_2015               4.570     5.33      6.470       7.59
# human_development_index            0.575     0.75      0.840       0.94
# gdp_percapita_2015              1525.340  6175.88  21788.230  100428.37
# alcohol_consumption_percapita      2.200     6.70      9.800      15.00
# health_spending_percapita_2015    89.710   389.38   1491.775    9491.09
# private_debt_2015                 26.025    59.97    121.820     399.13

# %%
# split features from labels
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('sui_per_100k_2015')
test_labels = test_features.pop('sui_per_100k_2015')

# %%
# the normalization layer
normalizer = preprocessing.Normalization()
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [    5.454     0.71  15212.88      6.465  1165.719    83.304]

# %%
first = np.array(train_features[:1])

with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[  4.79   0.62 929.1    3.3   64.17  20.5 ]]
#
# Normalized: [[-0.55 -0.55 -0.73 -0.76 -0.67 -0.79]]

# %%
# linear regression
alcohol = np.array(train_features['alcohol_consumption_percapita'])

alcohol_normalizer = preprocessing.Normalization(input_shape=[1,])
alcohol_normalizer.adapt(alcohol)

# %%
# build the sequential model
alcohol_model = tf.keras.Sequential([
    alcohol_normalizer,
    layers.Dense(units=1)
])

alcohol_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_4 (Normalizati (None, 1)                 3
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 5
# Trainable params: 2
# Non-trainable params: 3
# _________________________________________________________________

# %%
# run untrained model on the first 10 values
alcohol_model.predict(alcohol[:10])
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002624C700C80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[-1.191],
#        [-1.304],
#        [ 2.61 ],
#        [-2.095],
#        [-0.627],
#        [ 0.728],
#        [-2.132],
#        [-1.718],
#        [ 0.389],
#        [-0.288]], dtype=float32)

# %%
# configure training procedure
alcohol_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# execute the training
# %%time
history = alcohol_model.fit(
    train_features['alcohol_consumption_percapita'], train_labels,
    epochs=100,
    # suppress logging
    verbose=0,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2)

# %%
# visualize the model's training progress
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss  val_loss  epoch
# 95  3.679701  3.512984     95
# 96  3.680439  3.515155     96
# 97  3.681618  3.515565     97
# 98  3.682476  3.516568     98
# 99  3.681741  3.525234     99

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Error [Suicides]')
  plt.legend()
  plt.grid(True)

plot_loss(history)

# %%
# collect the results on the test set
test_results = {}

test_results['alcohol_model'] = alcohol_model.evaluate(
    test_features['alcohol_consumption_percapita'],
    test_labels, verbose=0)

# %%
x = tf.linspace(0.0, 25, 26)
y = alcohol_model.predict(x)

def plot_alcohol(x, y):
  plt.scatter(train_features['alcohol_consumption_percapita'], train_labels, label='Data')
  plt.plot(x, y, color='k', label='Predictions')
  plt.xlabel('Alcohol Consumption')
  plt.ylabel('Suicide Rate')
  plt.legend()

plot_alcohol(x,y)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002624CEF5510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# multiple inputs
linear_model = tf.keras.Sequential([
    normalizer,
    layers.Dense(units=1)
])

# make predictions with an untrained model
linear_model.predict(train_features[:10])
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002624CED4C80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[-0.612],
#        [-1.08 ],
#        [ 1.082],
#        [-0.733],
#        [ 0.6  ],
#        [ 0.436],
#        [-0.7  ],
#        [-0.52 ],
#        [-0.607],
#        [ 0.058]], dtype=float32)

# %%
linear_model.layers[1].kernel
# Out:
# <tf.Variable 'dense_13/kernel:0' shape=(6, 1) dtype=float32, numpy=
# array([[ 0.666],
#        [-0.431],
#        [ 0.018],
#        [ 0.467],
#        [ 0.124],
#        [ 0.039]], dtype=float32)>

# %%
# use the same compile and fit calls from single feature
linear_model.compile(
    optimizer=tf.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

history = linear_model.fit(
    train_features, train_labels,
    epochs=100,
    verbose=0,
    validation_split = 0.2)

# %%
plot_loss(history)

# %%
# collect the results on the test set
test_results['linear_model'] = linear_model.evaluate(
    test_features, test_labels, verbose=0)

# %%
# DNN regression
def build_and_compile_model(norm):
  model = keras.Sequential([
      norm,
      layers.Dense(64, activation='relu'),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
  ])

  model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001))
  return model

# %%
# start with one variable (alcohol)
dnn_alcohol_model = build_and_compile_model(alcohol_normalizer)
dnn_alcohol_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_4 (Normalizati (None, 1)                 3
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                128
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 4,356
# Trainable params: 4,353
# Non-trainable params: 3
# _________________________________________________________________

# %%
# train the model
history = dnn_alcohol_model.fit(
    train_features['alcohol_consumption_percapita'], train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)

plot_loss(history)

# %%
# plot the predictions
x = tf.linspace(0.0, 25, 26)
y = dnn_alcohol_model.predict(x)

plot_alcohol(x, y)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000262406F0620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# collect the result on the test set
test_results['dnn_alcohol_model'] = dnn_alcohol_model.evaluate(
    test_features['alcohol_consumption_percapita'], test_labels,
    verbose=0)

# %%
# full model
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization_3 (Normalizati (None, 6)                 13
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                448
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 4,686
# Trainable params: 4,673
# Non-trainable params: 13
# _________________________________________________________________

# %%
history = dnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=0, epochs=100)

plot_loss(history)

# %%
# collect test set results
test_results['dnn_model'] = dnn_model.evaluate(test_features, test_labels, verbose=0)
test_results
# Out:
# {'alcohol_model': 2.8265509605407715,
#  'linear_model': 2.430262565612793,
#  'dnn_alcohol_model': 3.277669668197632,
#  'dnn_model': 2.459664821624756}

# %%
# performance
# check the test-set performance
pd.DataFrame(test_results, index=['Mean absolute error [Suicide Rates]']).T
# Out:
#                    Mean absolute error [Suicide Rates]
# alcohol_model                                 2.826551
# linear_model                                  2.430263
# dnn_alcohol_model                             3.277670
# dnn_model                                     2.459665

# %%
# Make predictions
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [Suicide Rate]')
plt.ylabel('Predictions [Suicide Rate]')
lims = [0, 20]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# WARNING:tensorflow:7 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002624CD466A8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# error distribution
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel('Prediction Error [Suicide Rate]')
_ = plt.ylabel('Count')

# %%
# Evaluate the model using the testing data
model_loss, model_accuracy = dnn_model.evaluate(
    np.array(test_features), np.array(test_labels), verbose=0)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-db06f4b5d754> in <module>
#       1 # Evaluate the model using the testing data
#       2 model_loss, model_accuracy = dnn_model.evaluate(
# ----> 3     np.array(test_features), np.array(test_labels), verbose=0)
#       4 print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
#
# TypeError: cannot unpack non-iterable float object

# %%
np.array(test_features)
# Out:
# array([[    6.94,     0.89, 40441.05,    12.1 ,  4290.  ,   208.92],
#        [    4.33,     0.7 ,  6799.88,     8.4 ,   389.38,    36.47],
#        [    6.67,     0.83, 13574.17,     9.3 ,  1127.02,   145.43],
#        [    4.63,     0.58,  1766.01,     2.7 ,    81.62,    14.77],
#        [    3.66,     0.41,   769.26,     1.3 ,    44.69,    10.78],
#        [    4.57,     0.61,  1605.61,     5.7 ,    58.92,    58.55],
#        [    4.68,     0.65,  4989.8 ,     0.4 ,   156.84,     9.22],
#        [    6.94,     0.92, 61995.42,    13.  ,  4561.74,   323.12],
#        [    4.57,     0.43,   710.38,     5.8 ,    73.4 ,    12.95],
#        [    4.  ,     0.42,   751.17,     1.3 ,    30.88,    24.88],
#        [    6.3 ,     0.84, 24046.28,     8.1 ,  2243.47,   189.94],
#        [    5.48,     0.78,  9260.45,     3.6 ,   529.16,    95.14],
#        [    5.01,     0.63,  2875.26,     0.6 ,   148.04,    70.1 ],
#        [    5.07,     0.67,  2867.15,     6.6 ,   123.9 ,    51.98],
#        [    5.1 ,     0.83, 19252.63,    12.3 ,  1725.22,   196.7 ],
#        [    6.41,     0.84, 20627.93,     0.2 ,  1237.33,    65.24],
#        [    3.9 ,     0.47,  1218.76,     0.7 ,    53.41,    27.14],
#        [    7.36,     0.91, 50832.55,     9.2 ,  5595.03,   211.67],
#        [    7.59,     0.93, 82081.6 ,    11.5 ,  9382.79,   231.25],
#        [    6.46,     0.73,  5840.05,     8.3 ,   214.21,   132.3 ],
#        [    5.33,     0.76, 10948.72,     2.  ,   453.12,    79.23],
#        [    7.12,     0.92, 56803.47,     9.8 ,  9491.09,   147.71]])
